# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def score(n1,n2,n3):
    score = 1*n1 + 0.5*n2 + 0.2*n3
    return score

# %%
india = pd.read_csv("./india.csv")
brazil = pd.read_csv("./Brazil.csv")
USA = pd.read_csv("./USA.csv")
swit = pd.read_csv("./Switzerland.csv")
bangladesh = pd.read_csv("./bangladesh.csv")
nepal = pd.read_csv("./Nepal.csv")

# %%
india.dropna(inplace = True)
brazil.dropna(inplace = True)
USA.dropna(inplace = True)
swit.dropna(inplace = True)
bangladesh.dropna(inplace = True)
nepal.dropna(inplace = True)

# %%
high = "Sustainability Renewable Resources Conservation Biodiversity Emissions Carbon footprint Recycling Green energy Ecosystem Solar power Wind energy Climate change Circular economy Net-zero Decarbonization Waste reduction Water conservation Energy efficiency Pollution Habitat preservation Carbon neutrality Deforestation Sustainable agriculture Environmental impact Organic farming Solar panels Green infrastructure Reforestation Clean energy Zero waste Environmental protection Renewable resources Ecosystem restoration Sustainable materials Wildlife protection Greenhouse gases Ecological balance Resource management Eco-friendly Clean technology Low carbon Sustainable cities Climate action Environmental sustainability Water management Soil health Carbon capture Green policies Sustainable practices"
mod = "Environmentalism Public health Resilience Green jobs Urban planning Food security Eco-tourism Land management Agroforestry Sustainable fashion Energy transition Emission trading Green finance Environmental justice Land use Adaptation Climate resilience Green bonds Eco-design Sustainable tourism Organic products Natural resources Carbon offsetting Urban sustainability Sustainable business Pollution control Nature conservation Environmental awareness Carbon pricing Air quality Habitat loss Forest management Coastal erosion Environmental footprint Biodegradable Smart cities Nature-based solutions Low-emission zones Environmental standards Wildlife conservation Renewable industry Wastewater treatment Alternative energy Eco-innovation Social equity Renewable investment Green chemistry Climate finance Crop rotation Clean transport"
slight = "Urbanization Economy Policy-making Economic growth Innovation Infrastructure Corporate responsibility Stakeholders Social enterprise Public policy Community Technology Trade Development Economic policy Corporate governance Investment Education Job creation Livelihood Consumer behavior Ethics Market trends Leadership Business models Entrepreneurship Digital transformation Corporate social responsibility Diversity Public transportation Rural development Social impact Supply chain Global economy Partnerships Health systems Microfinance Civic engagement Transparency Social responsibility Government regulations Community development Knowledge sharing Green branding Rural economy Economic stability Policy frameworks Global partnerships Technological advancement Financial incentives"
high = ''.split(high)
mod = ''.split(mod)
slight = ''.split(slight)

# %%
itscore = {"highly":[],"moderately":[],"slightly":[]}
icscore = {"highly":[],"moderately":[],"slightly":[]}
it = []
ic = []
for i in india.index:
    current_title = india['Title'][i].split(" ")
    current_content = india['Content'][i].split(" ")
    h = 0
    m = 0
    s = 0
    for j in current_title:
        if j in high:
            h += 1
        if j in mod:
            m += 1
        if s in slight:
            s += 1
    itscore['highly'].append(h)
    itscore['moderately'].append(m)
    itscore['slightly'].append(s)
    it.append(score(h,m,s))
    h = 0
    m = 0
    s = 0
    for x in current_content:
        if x in high:
            h += 1
        if x in mod:
            m += 1
        if x in slight:
            s += 1
    icscore['highly'].append(h)
    icscore['moderately'].append(m)
    icscore['slightly'].append(s)
    ic.append(score(h,m,s))

# %%
btscore = {"highly":[],"moderately":[],"slightly":[]}
bcscore = {"highly":[],"moderately":[],"slightly":[]}
utscore = {"highly":[],"moderately":[],"slightly":[]}
ucscore = {"highly":[],"moderately":[],"slightly":[]}
stscore = {"highly":[],"moderately":[],"slightly":[]}
scscore = {"highly":[],"moderately":[],"slightly":[]}
batscore = {"highly":[],"moderately":[],"slightly":[]}
bacscore = {"highly":[],"moderately":[],"slightly":[]}
ntscore = {"highly":[],"moderately":[],"slightly":[]}
ncscore = {"highly":[],"moderately":[],"slightly":[]}
bt = []
bc = []
ut = []
uc = []
st = []
sc = []
bat = []
bac = []
nt = []
nc = []
for i in brazil.index:
    current_title = brazil['Title'][i].split(" ")
    current_content = brazil['Content'][i].split(" ")
    h = 0
    m = 0
    s = 0
    for j in current_title:
        if j in high:
            h += 1
        if j in mod:
            m += 1
        if s in slight:
            s += 1
    btscore['highly'].append(h)
    btscore['moderately'].append(m)
    btscore['slightly'].append(s)
    bt.append(score(h,m,s))
    h = 0
    m = 0
    s = 0
    for x in current_content:
        if x in high:
            h += 1
        if x in mod:
            m += 1
        if x in slight:
            s += 1
    bcscore['highly'].append(h)
    bcscore['moderately'].append(m)
    bcscore['slightly'].append(s)
    bc.append(score(h,m,s))
for i in USA.index:
    current_title = USA['title'][i].split(" ")
    current_content = USA['article'][i].split(" ")
    h = 0
    m = 0
    s = 0
    for j in current_title:
        if j in high:
            h += 1
        if j in mod:
            m += 1
        if s in slight:
            s += 1
    utscore['highly'].append(h)
    utscore['moderately'].append(m)
    utscore['slightly'].append(s)
    ut.append(score(h,m,s))
    h = 0
    m = 0
    s = 0
    for x in current_content:
        if x in high:
            h += 1
        if x in mod:
            m += 1
        if x in slight:
            s += 1
    ucscore['highly'].append(h)
    ucscore['moderately'].append(m)
    ucscore['slightly'].append(s)
    uc.append(score(h,m,s))
for i in swit.index:
    current_title = swit['Title'][i].split(" ")
    current_content = swit['Content'][i].split(" ")
    h = 0
    m = 0
    s = 0
    for j in current_title:
        if j in high:
            h += 1
        if j in mod:
            m += 1
        if s in slight:
            s += 1
    stscore['highly'].append(h)
    stscore['moderately'].append(m)
    stscore['slightly'].append(s)
    st.append(score(h,m,s))
    h = 0
    m = 0
    s = 0
    for x in current_content:
        if x in high:
            h += 1
        if x in mod:
            m += 1
        if x in slight:
            s += 1
    scscore['highly'].append(h)
    scscore['moderately'].append(m)
    scscore['slightly'].append(s)
    sc.append(score(h,m,s))
for i in bangladesh.index:
    current_title = bangladesh['Title'][i].split(" ")
    current_content = bangladesh['Content'][i].split(" ")
    h = 0
    m = 0
    s = 0
    for j in current_title:
        if j in high:
            h += 1
        if j in mod:
            m += 1
        if s in slight:
            s += 1
    batscore['highly'].append(h)
    batscore['moderately'].append(m)
    batscore['slightly'].append(s)
    bat.append(score(h,m,s))
    h = 0
    m = 0
    s = 0
    for x in current_content:
        if x in high:
            h += 1
        if x in mod:
            m += 1
        if x in slight:
            s += 1
    bacscore['highly'].append(h)
    bacscore['moderately'].append(m)
    bacscore['slightly'].append(s)
    bac.append(score(h,m,s))
for i in nepal.index:
    current_title = nepal['Title'][i].split(" ")
    current_content = nepal['Content'][i].split(" ")
    h = 0
    m = 0
    s = 0
    for j in current_title:
        if j in high:
            h += 1
        if j in mod:
            m += 1
        if s in slight:
            s += 1
    ntscore['highly'].append(h)
    ntscore['moderately'].append(m)
    ntscore['slightly'].append(s)
    nt.append(score(h,m,s))
    h = 0
    m = 0
    s = 0
    for x in current_content:
        if x in high:
            h += 1
        if x in mod:
            m += 1
        if x in slight:
            s += 1
    ncscore['highly'].append(h)
    ncscore['moderately'].append(m)
    ncscore['slightly'].append(s)
    nc.append(score(h,m,s))

# %%
itscore['T-score'] , itscore['C-score'] = it , ic
btscore['T-score'] , bcscore['C-score'] = bt , bc
utscore['T-score'] , ucscore['C-score'] = ut , uc
stscore['T-score'] , scscore['C-score'] = st , sc
batscore['T-score'] , bacscore['C-score'] = bat,bac
ntscore['T-score'] , ncscore['C-score'] = nt, nc

# %%
india['C-highly'] = icscore['highly']
india['C-moderately'] = icscore['moderately']
india['C-slightly'] = icscore['slightly']
india['C-score'] = ic
india['T-score'] = it
india['score'] = india['C-score'] + india['T-score']

# %%
brazil['C-highly'] = bcscore['highly']
brazil['C-moderately'] = bcscore['moderately']
brazil['C-slightly'] = bcscore['slightly']
brazil['C-score'] = bc
brazil['T-score'] = bt
brazil['score'] = brazil['C-score'] + brazil['T-score']
USA['C-highly'] = ucscore['highly']
USA['C-moderately'] = ucscore['moderately']
USA['C-slightly'] = ucscore['slightly']
USA['C-score'] = uc
USA['T-score'] = ut
USA['score'] = USA['C-score'] + USA['T-score']
swit['C-highly'] = scscore['highly']
swit['C-moderately'] = scscore['moderately']
swit['C-slightly'] = scscore['slightly']
swit['C-score'] = sc
swit['T-score'] = st
swit['score'] = swit['C-score'] + swit['T-score']
bangladesh['C-highly'] = bacscore['highly']
bangladesh['C-moderately'] = bacscore['moderately']
bangladesh['C-slightly'] = bacscore['slightly']
bangladesh['C-score'] = bac
bangladesh['T-score'] = bat
bangladesh['score'] = bangladesh['C-score'] + bangladesh['T-score']
nepal['C-highly'] = ncscore['highly']
nepal['C-moderately'] = ncscore['moderately']
nepal['C-slightly'] = ncscore['slightly']
nepal['C-score'] = nc
nepal['T-score'] = nt
nepal['score'] = nepal['C-score'] + nepal['T-score']

# %% [markdown]
# # Comparison of India with others

# %%
plt.bar(['India' , 'Brazil'] , [max(india['score']),max(brazil['score'])] , color = 'red' , width = 0.4)
plt.title("Comparison of India with Brazil (2 developing countries in the study)" , size = 10)
plt.xlabel("Country")
plt.ylabel("maximum score of a journal")
for i, value in enumerate([max(india['score']),max(brazil['score'])]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['India' , 'USA'] , [max(india['score']),149.9] , color = 'blue' , width = 0.4)
plt.title("Comparison of India with USA (USA being the developed country)" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([max(india['score']),149.9]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['India' , 'Switzerland'] , [max(india['score']),max(swit['score'])] , color = 'green' , width = 0.4)
plt.title("Comparison of India with Switzerland" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([max(india['score']),max(swit['score'])]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['India' , 'Bangladesh'] , [max(india['score']),max(bangladesh['score'])] , color = 'purple' , width = 0.4)
plt.title("Comparison of India with Bangladesh (Bangladesh being an under-developed country)" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([max(india['score']),max(bangladesh['score'])]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['India' , 'Nepal'] , [max(india['score']),143.5] , color = 'violet' , width = 0.4)
plt.title("Comparison of India with Nepal (Nepal being an under-developed country)" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([max(india['score']),143.5]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['Switzerland' , 'USA'] , [max(swit['score']),149.9] , color = 'black' , width = 0.4)
plt.title("Comparison of Switzerland with USA (2 developed countries in the study)" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([max(swit['score']),149.9]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['Switzerland' , 'brazil'] , [max(swit['score']),max(brazil['score'])] , color = 'orange' , width = 0.4)
plt.title("Comparison of Switzerland with Brazil" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([max(swit['score']),max(brazil['score'])]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['Switzerland' , 'bangladesh'] , [max(swit['score']),max(bangladesh['score'])] , color = 'green' , width = 0.4)
plt.title("Comparison of Switzerland with Bangladesh" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([max(swit['score']),max(bangladesh['score'])]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['Switzerland' , 'Nepal'] , [max(swit['score']),143.5] , color = 'beige' , width = 0.4)
plt.title("Comparison of Switzerland with Nepal" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([max(swit['score']),143.5]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['USA' , 'brazil'] , [149.9,max(brazil['score'])] , color = 'maroon' , width = 0.4)
plt.title("Comparison of USA with Brazil" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([149.9,max(brazil['score'])]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['USA' , 'Bangladesh'] , [149.9,max(bangladesh['score'])] , color = 'tomato' , width = 0.4)
plt.title("Comparison of USA with Bangladesh" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([149.9,max(bangladesh['score'])]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['USA' , 'Nepal'] , [149.9,143.5] , color = 'olive' , width = 0.4)
plt.title("Comparison of USA with Nepal" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([149.9,143.5]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['Brazil' , 'Bangladesh'] , [max(brazil['score']),max(bangladesh['score'])] , color = 'lightgreen' , width = 0.4)
plt.title("Comparison of Brazil with Bangladesh" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([max(brazil['score']),max(bangladesh['score'])]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['Brazil' , 'Nepal'] , [max(brazil['score']),143.5] , color = 'pink' , width = 0.4)
plt.title("Comparison of Brazil with Nepal" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([max(brazil['score']),143.5]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
plt.bar(['Bangladesh' , 'Nepal'] , [max(bangladesh['score']),143.5] , color = 'crimson' , width = 0.4)
plt.title("Comparison of Bangladesh with Nepal" , size = 10)
plt.xlabel("Country" , size = 8)
plt.ylabel("maximum score of a journal" , size = 8)
for i, value in enumerate([max(bangladesh['score']),143.5]):
    plt.text(i, value + 0.5, str(value), ha='center', va='bottom')

# %%
USA.columns = ['Unnamed: 0', 'Title', 'Content', 'C-highly', 'C-moderately','C-slightly', 'C-score', 'T-score', 'score']

# %%
swit.drop("Unnamed: 0",axis = 1, inplace = True)
swit.drop('date',axis = 1 , inplace = True)
USA.drop("Unnamed: 0",axis = 1 , inplace = True)

# %%
developed = pd.concat([USA,swit])

# %%
brazil.drop("Unnamed: 0" , axis = 1 , inplace = True)
india.drop("Unnamed: 0" , axis = 1 , inplace = True)

# %%
developing = pd.concat([india,brazil])

# %%
nepal.drop("Unnamed: 0" , axis = 1 , inplace = True)
bangladesh.drop("Unnamed: 0" , axis = 1 , inplace = True)

# %%
under = pd.concat([nepal,bangladesh])

# %%
developed.to_csv("modelDeveloped.csv")
developing.to_csv("modelDeveloping.csv")
under.to_csv("under.csv")
